# %%
from sklearn.datasets import make_regression
import numpy as np

# %%
X, y = make_regression(n_samples=4, n_features=1, n_informative=1, n_targets=1, noise=80, random_state=13)

# %%
import matplotlib.pyplot as plt
plt.scatter(X, y)

# %%
#Using OLS 
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(X,y)
# Out:
# LinearRegression()

# %%
reg.coef_, reg.intercept_
# Out:
# (array([78.35063668]), 26.15963284313262)

# %%
plt.scatter(X, y)
plt.plot(X, reg.predict(X), color="red")

# %%
# let assume the m has a constant value of 
m = reg.coef_[0]
b = 0

# %%
m
# Out:
# 78.35063667947497

# %%
y_pred = ((m * X) + 0).reshape(4)
y_pred
# Out:
# array([-55.81626194,  35.3997844 ,  -3.48684452,  59.05807568])

# %%
plt.scatter(X, y)
plt.plot(X, reg.predict(X), color="red", label="OLS")
plt.plot(X, y_pred, color="#00a65a", label="b = 0")
plt.legend()
plt.show()

# %%
X, y
# Out:
# (array([[-0.71239066],
#         [ 0.45181234],
#         [-0.04450308],
#         [ 0.75376638]]),
#  array([  7.21786552,  16.04609925, -27.83756166, 144.36688189]))

# %%
def loss_function(b):
    return -2 * np.sum(y - m*X.ravel() - b)

# %%
loss_function(0)
# Out:
# -209.27706274506096

# %%
# learning Rate
lr = 0.1

# %%
def step_size(b):
    return loss_function(b) * lr

# %%
step_size(0)
# Out:
# -20.927706274506097

# %%
b = b - step_size(b)

# %%
b
# Out:
# 20.927706274506097

# %%
def y_prediction(b):
    return ((m * X) + b).reshape(4)

# %%
def plotting(y_pred):
    plt.scatter(X, y)
    plt.plot(X, reg.predict(X), color="red", label="OLS")
    plt.plot(X, y_pred, color="#00a65a", label="b = {b}")
    plt.legend()
    plt.show()

# %%
plotting(y_prediction(b))

# %%
b = b - step_size(b)

# %%
plotting(y_prediction(b))

# %%
b = b - step_size(b)

# %%
plotting(y_prediction(b))

# %%
plotting(y_prediction(100))

# %% [markdown]
# # Eaxmple 2

# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np

# %%
X, y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1, noise=20)

# %%
X, y
# Out:
# (array([[ 0.68630445],
#         [ 0.79886629],
#         [-1.69322421],
#         [ 0.64593707],
#         [ 0.54661908],
#         [-0.09099899],
#         [ 0.30538934],
#         [ 1.42091878],
#         [-1.22888978],
#         [ 1.46916984],
#         [ 1.24535451],
#         [-0.49957426],
#         [-0.87502241],
#         [-0.02607627],
#         [-0.18275282],
#         [-0.20694111],
#         [ 0.7150594 ],
#         [ 0.22127912],
#         [-0.1661047 ],
#         [-0.31270672],
#         [-0.19046145],
#         [-2.01261376],
#         [-0.12552889],
#         [ 0.51960425],
#         [-0.97461402],
#         [ 0.7724095 ],
#         [ 1.19789307],
#         [-0.2940867 ],
#         [-1.39862999],
#         [ 0.40854619],
#         [-0.68190125],
#         [-0.14995741],
#         [-0.92209853],
#         [ 0.99128167],
#         [ 0.32640512],
#         [-1.34733213],
#         [-0.09593302],
#         [-0.80328318],
#         [ 0.67903661],
#         [ 0.73303454],
#         [-0.42127735],
#         [-0.25312986],
#         [-0.19457212],
#         [-0.26306917],
#         [-0.86874035],
#         [-0.54446792],
#         [ 2.15807045],
#         [-1.22659758],
#         [ 1.95811852],
#         [-1.06397016],
#         [-0.20768042],
#         [-1.02135661],
#         [-0.17132788],
#         [-0.98481193],
#         [-1.19084629],
#         [-0.47175698],
#         [ 0.15460831],
#         [ 0.05423449],
#         [ 2.13251476],
#         [-1.20431118],
#         [ 0.38453051],
#         [-1.43075831],
#         [ 2.23697151],
#         [ 1.00539469],
#         [ 0.30941468],
#         [ 0.3558406 ],
#         [ 2.93098995],
#         [ 0.20907452],
#         [ 0.70461013],
#         [ 1.60547852],
#         [ 0.10242027],
#         [ 0.19084253],
#         [-0.07114503],
#         [-0.42493782],
#         [-0.62196399],
#         [ 1.07297985],
#         [ 0.62617892],
#         [-0.34295536],
#         [-0.59012085],
#         [-1.87725812],
#         [-0.07671603],
#         [ 2.14060522],
#         [-1.03171921],
#         [ 0.29926703],
#         [-0.56086977],
#         [-1.46411284],
#         [-2.63346852],
#         [ 1.27418603],
#         [-0.15638969],
#         [-1.38283645],
#         [-2.93365881],
#         [ 0.72334507],
#         [-0.2114674 ],
#         [ 0.02600194],
#         [-2.28590546],
#         [-1.15422219],
#         [ 0.63116108],
#         [ 0.23345277],
#         [ 0.32816691],
#         [ 0.22352283]]),
#  array([  33.08246916,   46.38789295,  -56.32040915,   59.4419177 ,
#           26.89032138,  -58.6550158 ,    6.81232069,   68.58369838,
#          -61.24534442,   79.6981443 ,   57.79982657,  -55.87621142,
#          -44.07674631,   11.09850663,   -8.67377842,  -17.97250127,
#           -4.84858996,   17.5935175 ,   -4.49024479,  -39.58087045,
#           10.22982619,  -62.79184714,   -9.76687736,   17.86996624,
#          -43.33080773,   46.82839188,   64.41112398,   -9.62692771,
#          -93.97959735,   38.25374136,  -49.68932658,  -36.96885844,
#          -20.4461783 ,   63.80375082,   35.03764903, -103.3160343 ,
#           -2.30511274,  -18.74366655,   -3.11586008,   51.04941364,
#          -45.8836535 ,  -18.32956065,   -1.32048112,  -14.0237206 ,
#          -25.29121424,  -21.57444215,  142.97537991,  -76.71959742,
#          122.88083895,  -88.45941751,  -47.36613976,  -73.10030056,
#           -4.0780304 ,  -24.32496864,  -62.82330505,  -12.65878072,
#           -9.67916304,   15.45882755,  117.08016411,  -75.76466685,
#           17.04498009,  -64.94945835,  102.88413825,   81.42016104,
#           21.65142604,    2.47614551,  113.9870174 ,   30.05470514,
#           53.51765659,  111.58680351,   18.06828248,    9.45511665,
#          -69.44561005,  -21.79240174,  -35.76212523,   51.09791925,
#           60.44036556,   -3.67608459,  -38.0913531 , -112.43404353,
#           -5.6060814 ,  102.91817067,  -23.31749036,   15.36485343,
#          -41.65643076,  -77.17936201, -114.49742479,   60.45019146,
#            1.99343014,  -65.71225929, -143.23176691,   75.47237298,
#           -4.33679069,  -19.13434397, -126.15461873,  -46.55829601,
#            2.77682806,   32.79540824,   14.4055005 ,   -1.52386481]))

# %%
plt.scatter(X, y)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(X, y)
# Out:
# LinearRegression()

# %%
m = reg.coef_[0]

# %%
m, reg.intercept_
# Out:
# (51.24205376931518, -0.08764781675762512)

# %%
plt.scatter(X, y)
plt.plot(X, reg.predict(X), color="red")

# %% [markdown]
# Own Gradient Decent

# %%
class GDRegression:
    
    def __init__(self, learning_rate, epochs):
        self.b = -120,
        self.m = 51.24205376931518
        self.lr = learning_rate
        self.epochs = epochs
    
    def fit(self, X, y):
        
        for i in range(self.epochs):
            loss_slope = -2 * np.sum(y - self.m*X.ravel() - self.b)
            self.b = self.b - (self.lr * loss_slope)
            print(loss_slope, self.b)
            
        print(self.b)

# %%
gd = GDRegression(0.001, 100)

# %%
gd.fit(X, y)
# Out:
# -23982.470436648477 [-96.01752956]
# -19185.976349318786 [-76.83155321]
# -15348.781079455024 [-61.48277213]
# -12279.024863564018 [-49.20374727]
# -9823.219890851215 [-39.38052738]
# -7858.575912680972 [-31.52195147]
# -6286.860730144777 [-25.23509074]
# -5029.488584115821 [-20.20560215]
# -4023.590867292658 [-16.18201129]
# -3218.8726938341256 [-12.96313859]
# -2575.098155067301 [-10.38804044]
# -2060.0785240538407 [-8.32796191]
# -1648.0628192430727 [-6.67989909]
# -1318.450255394458 [-5.36144884]
# -1054.7602043155664 [-4.30668863]
# -843.8081634524533 [-3.46288047]
# -675.0465307619622 [-2.78783394]
# -540.0372246095699 [-2.24779672]
# -432.02977968765606 [-1.81576694]
# -345.62382375012487 [-1.47014311]
# -276.4990590000998 [-1.19364405]
# -221.19924720007984 [-0.97244481]
# -176.95939776006387 [-0.79548541]
# -141.5675182080511 [-0.65391789]
# -113.25401456644082 [-0.54066388]
# -90.60321165315256 [-0.45006066]
# -72.48256932252224 [-0.37757809]
# -57.986055458017816 [-0.31959204]
# -46.38884436641412 [-0.27320319]
# -37.111075493131466 [-0.23609212]
# -29.688860394505042 [-0.20640326]
# -23.751088315603937 [-0.18265217]
# -19.000870652483396 [-0.1636513]
# -15.200696521986767 [-0.1484506]
# -12.160557217589396 [-0.13629005]
# -9.728445774071332 [-0.1265616]
# -7.7827566192570465 [-0.11877884]
# -6.226205295405556 [-0.11255264]
# -4.980964236324443 [-0.10757167]
# -3.984771389059489 [-0.1035869]
# -3.187817111247803 [-0.10039909]
# -2.5502536889982252 [-0.09784883]
# -2.0402029511985518 [-0.09580863]
# -1.6321623609588087 [-0.09417647]
# -1.305729888767324 [-0.09287074]
# -1.0445839110134685 [-0.09182615]
# -0.8356671288111883 [-0.09099049]
# -0.6685337030488867 [-0.09032195]
# -0.5348269624390909 [-0.08978712]
# -0.42786156995114766 [-0.08935926]
# -0.342289255960857 [-0.08901697]
# -0.2738314047689059 [-0.08874314]
# -0.21906512381510623 [-0.08852408]
# -0.1752520990520665 [-0.08834883]
# -0.14020167924130789 [-0.08820862]
# -0.11216134339321115 [-0.08809646]
# -0.08972907471465064 [-0.08800673]
# -0.07178325977167788 [-0.08793495]
# -0.05742660781748654 [-0.08787752]
# -0.04594128625390326 [-0.08783158]
# -0.03675302900297339 [-0.08779483]
# -0.029402423202547823 [-0.08776543]
# -0.02352193856180662 [-0.0877419]
# -0.018817550849767883 [-0.08772309]
# -0.015054040679423508 [-0.08770803]
# -0.012043232543788918 [-0.08769599]
# -0.00963458603510503 [-0.08768636]
# -0.007707668828089709 [-0.08767865]
# -0.006166135062446898 [-0.08767248]
# -0.004932908049767093 [-0.08766755]
# -0.003946326440058101 [-0.0876636]
# -0.0031570611519100567 [-0.08766045]
# -0.002525648921444912 [-0.08765792]
# -0.002020519137211352 [-0.0876559]
# -0.0016164153096305256 [-0.08765428]
# -0.001293132247944584 [-0.08765299]
# -0.0010345057982057426 [-0.08765195]
# -0.0008276046386583857 [-0.08765113]
# -0.0006620837108428645 [-0.08765047]
# -0.0005296669685677102 [-0.08764994]
# -0.0004237335750723048 [-0.08764951]
# -0.00033898685997968414 [-0.08764917]
# -0.00027118948796100995 [-0.0876489]
# -0.00021695159048817914 [-0.08764868]
# -0.00017356127239764874 [-0.08764851]
# -0.000138849017702114 [-0.08764837]
# -0.0001110792141219008 [-0.08764826]
# -8.88633713600484e-05 [-0.08764817]
# -7.109069729693829e-05 [-0.0876481]
# -5.687255764996735e-05 [-0.08764804]
# -4.5498046240766143e-05 [-0.087648]
# -3.639843694713818e-05 [-0.08764796]
# -2.911874952005178e-05 [-0.08764793]
# -2.329499955777692e-05 [-0.08764791]
# -1.8635999737171005e-05 [-0.08764789]
# -1.490879973431447e-05 [-0.08764788]
# -1.1927039739845213e-05 [-0.08764786]
# -9.541631925458205e-06 [-0.08764785]
# -7.633305479259889e-06 [-0.08764785]
# -6.106644462988697e-06 [-0.08764784]
# [-0.08764784]

# %% [markdown]
# # For Both m and b

# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import cross_val_score

# %%
X, y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1, noise=20, random_state=13)

# %%
plt.scatter(X, y)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X, y)
# Out:
# LinearRegression()

# %%
lr.coef_, lr.intercept_
# Out:
# (array([27.82809103]), -2.29474455867698)

# %%
y_pred = lr.predict(X)

# %%
plt.scatter(X, y)
plt.plot(X, y_pred, color="red")

# %%
np.mean(cross_val_score(lr, X, y, scoring='r2', cv=10))
# Out:
# 0.6375011587464419

# %%
class GDRegression:
    
    def __init__(self, learning_rate, epochs):
        self.m = 100
        self.b = -120
        self.lr = learning_rate
        self.epochs = epochs
    
    def fit(self, X, y):
        for i in range(self.epochs):
            loss_slope_b = -2 * np.sum(y - self.m*X.ravel() - self.b)
            self.b = self.b - (self.lr * loss_slope_b)
            
            loss_slope_m = -2 * np.sum((y - self.m*X.ravel() - self.b) * X.ravel())
            self.m = self.m - (self.lr * loss_slope_m)
        
        print(self.b, self.m)
        
    def predict(self, X):
        return self.m * X + self.b

# %%
gd = GDRegression(0.01, 1000)

# %%
gd.fit(X, y)
# Out:
# -2.2947445586769852 27.82809103252014

# %%
plt.scatter(X, y)
plt.plot(X, gd.predict(X), color="green")

# %%
from sklearn.model_selection import train_test_split
X_train, y_train, X_test, y_test = train_test_split(X,y, test_size=0.2,random_state=2)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y, y_pred)
# Out:
# 0.7035182396294911

# %% [markdown]
# # For Multiple Dim

# %%
from sklearn.datasets import load_diabetes

import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
X, y = load_diabetes(return_X_y=True)

# %%
X.shape, y.shape
# Out:
# ((442, 10), (442,))

# %%
X_train, X_test, y_train , y_test = train_test_split(X, y, test_size=0.2,random_state=2)

# %%
X_train.shape, y_train.shape
# Out:
# ((353, 10), (353,))

# %%
reg = LinearRegression()

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
reg.intercept_ , reg.coef_
# Out:
# (151.88331005254167,
#  array([  -9.15865318, -205.45432163,  516.69374454,  340.61999905,
#         -895.5520019 ,  561.22067904,  153.89310954,  126.73139688,
#          861.12700152,   52.42112238]))

# %%
y_pred = reg.predict(X_test)
r2_score(y_test, y_pred)
# Out:
# 0.4399338661568968

# %%
class MGDRegression:
    
    def __init__(self, learning_rate, epochs):
        self.coef_ = None
        self.intercept_ = None
        self.lr = learning_rate
        self.epochs = epochs
        
    def fit(self, X_train, y_train):
        self.intercept_ = 0
        self.coef_ = np.ones(X_train.shape[1])
        
        for i in range(self.epochs):
            
            y_hat = np.dot(X_train, self.coef_) + self.intercept_
            intercept_der = -2 * np.mean(y_train - y_hat)
            self.intercept_ = self.intercept_ - (self.lr* intercept_der)
                
            coef_der = -2 * np.dot((y_train - y_hat), X_train)/X_train.shape[0]
            self.coef_ = self.coef_ - (self.lr * coef_der)
    
    
        
    def predict(self, X_test):
        return np.dot(X_test, self.coef_) + self.intercept_

# %%
gd = MGDRegression(0.1, 1000)

# %%
gd.fit(X_train, y_train)

# %%
gd.intercept_, gd.coef_
# Out:
# (151.94042847773682,
#  array([  62.27835432,  -24.14017912,  262.40285385,  192.20751489,
#           39.48809013,   10.26886323, -142.50597903,  124.33312557,
#          244.33510843,  119.34350233]))

# %%
y_pred = gd.predict(X_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.397169838804874

# %% [markdown]
# # stochastic Gradient Decent

# %%
from sklearn.datasets import load_diabetes

import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
X, y = load_diabetes(return_X_y=True)

# %%
X.shape, y.shape
# Out:
# ((442, 10), (442,))

# %%
X_train, X_test, y_train , y_test = train_test_split(X, y, test_size=0.2,random_state=2)

# %%
X_train.shape, y_train.shape
# Out:
# ((353, 10), (353,))

# %%
reg = LinearRegression()

# %%
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
reg.intercept_, reg.coef_
# Out:
# (151.88331005254167,
#  array([  -9.15865318, -205.45432163,  516.69374454,  340.61999905,
#         -895.5520019 ,  561.22067904,  153.89310954,  126.73139688,
#          861.12700152,   52.42112238]))

# %%
y_pred = reg.predict(X_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.4399338661568968

# %%
class SGDRegression:
    
    def __init__(self, learning_rate, epochs):
        self.coef_ = None
        self.intercept_ = None
        self.lr = learning_rate
        self.epochs = epochs
        
    def fit(self, X_train, y_train):
        self.intercept_ = 0
        self.coef_ = np.ones(X_train.shape[1])
        
        for i in range(self.epochs):
            for j in range(X_train.shape[0]):
                idx = np.random.randint(0,X_train.shape[0])
                
                y_hat = np.dot(X_train[idx],self.coef_) + self.intercept_
                
                intercept_der = -2 * (y_train[idx] - y_hat)
                self.intercept_ = self.intercept_ - (self.lr * intercept_der)
                
                coef_der = -2 * np.dot((y_train[idx] - y_hat),X_train[idx])
                self.coef_ = self.coef_ - (self.lr * coef_der)
                
            
            
    
        
    def predict(self, X_test):
        return np.dot(X_test, self.coef_) + self.intercept_

# %%
sgd = SGDRegression(0.01, 50)

# %%
sgd.fit(X_train, y_train)

# %%
sgd.intercept_ , sgd.coef_
# Out:
# (159.7363181534877,
#  array([  61.12009856,  -62.53996004,  349.72848507,  247.93421706,
#           24.62344764,  -23.38376068, -174.78895184,  135.03657506,
#          324.05369349,  131.05699637]))

# %%
y_pred = sgd.predict(X_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.4204522601384252

# %% [markdown]
# # Mini-Batch GD

# %%
from sklearn.datasets import load_diabetes

import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
X, y = load_diabetes(return_X_y=True)

# %%
X_train, X_test, y_train , y_test = train_test_split(X, y, test_size=0.2,random_state=2)

# %%
class MINIGDRegression:
    
    def __init__(self, batch_size, learning_rate, epochs):
        self.coef_ = None
        self.intercept_ = None
        self.batch_size = batch_size
        self.lr = learning_rate
        self.epochs = epochs
        
    def fit(self, X_train, y_train):
        self.intercept_ = 0
        self.coef_ = np.ones(X_train.shape[1])
        
        for i in range(self.epochs):
            for j in range(self.batch_size):
                idx = np.random.randint(0,X_train.shape[0])
                
                y_hat = np.dot(X_train[idx],self.coef_) + self.intercept_
                
                intercept_der = -2 * (y_train[idx] - y_hat)
                self.intercept_ = self.intercept_ - (self.lr * intercept_der)
                
                coef_der = -2 * np.dot((y_train[idx] - y_hat),X_train[idx])
                self.coef_ = self.coef_ - (self.lr * coef_der)
                
            
            
    
        
    def predict(self, X_test):
        return np.dot(X_test, self.coef_) + self.intercept_

# %%
minigd = MINIGDRegression(10, 0.01, 50)

# %%
minigd.fit(X, y)

# %%
minigd.intercept_ , minigd.coef_
# Out:
# (159.77901782277317,
#  array([  4.68115487,   2.93061931,  21.90425493,  16.33916045,
#           5.77331186,   5.53898498, -12.94512827,  13.6005757 ,
#          18.24442467,  13.41931128]))
